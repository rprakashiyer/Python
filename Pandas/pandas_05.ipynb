# %% [markdown]
# <a href="https://colab.research.google.com/github/rprakashiyer/Python/blob/main/Pandas/pandas_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# https://drive.google.com/file/d/11itYrYHXKYS4_d_RkxVwE7-GwIR8Dgr1/view?usp=sharing

# %%
# !gdown 11itYrYHXKYS4_d_RkxVwE7-GwIR8Dgr1
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11itYrYHXKYS4_d_RkxVwE7-GwIR8Dgr1
# To: /content/Pfizer_1.csv
# 100% 1.51k/1.51k [00:00<00:00, 2.20MB/s]

# %%
# https://drive.google.com/file/d/1JJnPzbvSu9hC9U8iGgd6HFLxyoIFwjbD/view?usp=sharing

# %%
# !gdown 1JJnPzbvSu9hC9U8iGgd6HFLxyoIFwjbD
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1JJnPzbvSu9hC9U8iGgd6HFLxyoIFwjbD
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 60.4MB/s]

# %%
# https://drive.google.com/file/d/1ed6Xj1Qkt3-zqIamiV7Bq5ct8MKPszL4/view?usp=sharing

# %%
# !gdown 1ed6Xj1Qkt3-zqIamiV7Bq5ct8MKPszL4
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ed6Xj1Qkt3-zqIamiV7Bq5ct8MKPszL4
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 67.4MB/s]

# %%
movies = pd.read_csv('/content/movies.csv', index_col=0)
directors = pd.read_csv('/content/directors.csv',index_col=0)
data = movies.merge(directors, how='left', left_on='director_id',right_on='id')  
data.drop(['director_id','id_y'],axis=1,inplace=True)

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data['budget'] = (data['budget']/1000000).round(2)
data['revenue'] = (data['revenue']/1000000).round(2)
data
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 1     43598  300.00         139   961.00
# 2     43599  245.00         107   880.67
# 3     43600  250.00         112  1084.94
# 4     43602  258.00         115   890.87
# ...     ...     ...         ...      ...
# 1460  48363    0.00           3     0.32
# 1461  48370    0.03          19     3.15
# 1462  48375    0.00           7     0.00
# 1463  48376    0.00           3     0.00
# 1464  48395    0.22          14     2.04
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %% [markdown]
# ### Transform works on one particular column

# %%
def calc_exp(x):
  x = x - x.mean()
  x['budget']

data.groupby("director_name").transform(calc_exp)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'budget'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-67c39a3c6b58> in <module>
#       3   x['budget']
#       4
# ...

# %% [markdown]
# ### hence we need to select the column we need to work and then perform the function on that column

# %%
def calc_exp(x):
  x = x - x.mean()
  return x

data["exp_or_inexp"] =data.groupby("director_name")['budget'].transform(calc_exp)
data
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 1     43598  300.00         139   961.00
# 2     43599  245.00         107   880.67
# 3     43600  250.00         112  1084.94
# 4     43602  258.00         115   890.87
# ...     ...     ...         ...      ...
# 1460  48363    0.00           3     0.32
# 1461  48370    0.03          19     3.15
# 1462  48375    0.00           7     0.00
# 1463  48376    0.00           3     0.00
# 1464  48395    0.22          14     2.04
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %%
data.shape
# Out:
# (1465, 13)

# %% [markdown]
# ### Using apply() we can pass the dataframe, and work with multiple columns and perform the operation inside the function

# %%
def calc_risky(x):
  x["risky_status"] = (x["budget"] - x["revenue"].mean()) >= 0
  return x

data_risky=data.groupby("director_name").apply(calc_risky)
data_risky
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 1     43598  300.00         139   961.00
# 2     43599  245.00         107   880.67
# 3     43600  250.00         112  1084.94
# 4     43602  258.00         115   890.87
# ...     ...     ...         ...      ...
# 1460  48363    0.00           3     0.32
# 1461  48370    0.03          19     3.15
# 1462  48375    0.00           7     0.00
# 1463  48376    0.00           3     0.00
# 1464  48395    0.22          14     2.04
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %%
data_risky[data_risky["risky_status"]==True][["title","director_name"]]
# Out:
#                                             title   director_name
# 7                               Quantum of Solace    Marc Forster
# 12    Pirates of the Caribbean: On Stranger Tides    Rob Marshall
# 15                                     Robin Hood    Ridley Scott
# 20                                     Battleship      Peter Berg
# 24                          X-Men: The Last Stand    Brett Ratner
# ...                                           ...             ...
# 1347                          The Sweet Hereafter     Atom Egoyan
# 1349                         90 Minutes in Heaven  Michael Polish
# 1351                                Light Sleeper   Paul Schrader
# 1356                           Dying of the Light   Paul Schrader
# 1383                  In the Name of the King III        Uwe Boll
#
# [131 rows x 2 columns]

# %%
data_risky.loc[data_risky["risky_status"]==True].head(10)
# Out:
#      id_x  budget  popularity  revenue  \
# 7   43608   200.0         107   586.09
# 12  43614   380.0         135  1045.71
# 15  43618   200.0          37   310.67
# 20  43624   209.0          64   303.03
# 24  43630   210.0           3   459.36
# 29  43640   200.0          71   371.35
# 31  43642   200.0          81   531.86
# 47  43666   170.0          32   185.77
# 53  43672   175.0          44   264.22
# 69  43709   155.0          39   167.30
#
#                                           title  vote_average  vote_count  \
# 7                             Quantum of Solace           6.1        2965
# 12  Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 15                                   Robin Hood           6.2        1398
# 20                                   Battleship           5.5        2114
# 24                        X-Men: The Last Stand           6.3        3525
# 29                         Terminator Salvation           5.9        2463
# ...

# %% [markdown]
# ### To find the mean budget and revenue of movies by Rob Marshall, from the highly risky DataFrame

# %%
data_risky.loc[data["director_name"]=="Rob Marshall",["budget","revenue"]].mean()
# Out:
# budget     128.000
# revenue    356.292
# dtype: float64

# %%
data.loc[:,["revenue","budget","vote_average"]]
# Out:
#       revenue  budget  vote_average
# 0     2787.97  237.00           7.2
# 1      961.00  300.00           6.9
# 2      880.67  245.00           6.3
# 3     1084.94  250.00           7.6
# 4      890.87  258.00           5.9
# ...       ...     ...           ...
# 1460     0.32    0.00           7.9
# 1461     3.15    0.03           7.4
# 1462     0.00    0.00           6.0
# 1463     0.00    0.00           6.4
# 1464     2.04    0.22           6.6
#
# [1465 rows x 3 columns]

# %%
data.loc[:,["revenue","budget","vote_average"]].apply(np.mean,axis=0)
# Out:
# revenue         143.253952
# budget           48.022949
# vote_average      6.368191
# dtype: float64

# %%
data.apply?

# %%
df = pd.read_csv('/content/Pfizer_1.csv')
df
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %% [markdown]
# ### Restructuring of data, to make it comprehensible

# %%
pd.Series([1,np.nan,2,3,np.nan])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    3.0
# 4    NaN
# dtype: float64

# %%
pd.Series([1,np.nan,2,3,np.nan,None])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    3.0
# 4    NaN
# 5    NaN
# dtype: float64

# %%
pd.Series(["1","np.nan","2","3","np.nan",None])
# Out:
# 0         1
# 1    np.nan
# 2         2
# 3         3
# 4    np.nan
# 5      None
# dtype: object

# %%
df.isna()
# Out:
#      Date  Drug_Name  Parameter  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00  \
# 0   False      False      False    False    False     True    False    False
# 1   False      False      False    False    False     True    False    False
# 2   False      False      False     True    False    False     True    False
# 3   False      False      False     True    False    False     True    False
# 4   False      False      False    False     True     True    False     True
# 5   False      False      False    False     True     True    False     True
# 6   False      False      False    False    False    False    False    False
# 7   False      False      False    False    False    False    False    False
# 8   False      False      False    False    False     True    False    False
# 9   False      False      False    False    False     True    False    False
# 10  False      False      False    False    False    False     True    False
# ...

# %%
df.isnull()
# Out:
#      Date  Drug_Name  Parameter  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00  \
# 0   False      False      False    False    False     True    False    False
# 1   False      False      False    False    False     True    False    False
# 2   False      False      False     True    False    False     True    False
# 3   False      False      False     True    False    False     True    False
# 4   False      False      False    False     True     True    False     True
# 5   False      False      False    False     True     True    False     True
# 6   False      False      False    False    False    False    False    False
# 7   False      False      False    False    False    False    False    False
# 8   False      False      False    False    False     True    False    False
# 9   False      False      False    False    False     True    False    False
# 10  False      False      False    False    False    False     True    False
# ...

# %%
df.isna().sum()
# Out:
# Date         0
# Drug_Name    0
# Parameter    0
# 1:30:00      2
# 2:30:00      2
# 3:30:00      6
# 4:30:00      4
# 5:30:00      2
# 6:30:00      0
# 7:30:00      2
# 8:30:00      4
# 9:30:00      2
# 10:30:00     0
# 11:30:00     2
# 12:30:00     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       18 non-null     object
#  1   Drug_Name  18 non-null     object
#  2   Parameter  18 non-null     object
#  3   1:30:00    16 non-null     float64
#  4   2:30:00    16 non-null     float64
#  5   3:30:00    12 non-null     float64
#  6   4:30:00    14 non-null     float64
#  7   5:30:00    16 non-null     float64
#  8   6:30:00    18 non-null     int64
#  9   7:30:00    16 non-null     float64
#  10  8:30:00    14 non-null     float64
#  11  9:30:00    16 non-null     float64
#  12  10:30:00   18 non-null     int64
#  13  11:30:00   16 non-null     float64
#  14  12:30:00   18 non-null     int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 2.2+ KB

# %%
df.dropna()
# Out:
#           Date               Drug_Name    Parameter  1:30:00  2:30:00  \
# 14  17-10-2020     docetaxel injection  Temperature     12.0     13.0
# 15  17-10-2020     docetaxel injection     Pressure     20.0     22.0
# 16  17-10-2020  ketamine hydrochloride  Temperature     13.0     14.0
# 17  17-10-2020  ketamine hydrochloride     Pressure      8.0      9.0
#
#     3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 14     14.0     15.0     16.0       17     18.0     19.0     20.0        21
# 15     22.0     22.0     22.0       23     25.0     26.0     27.0        28
# 16     15.0     16.0     17.0       18     19.0     20.0     21.0        22
# 17     10.0     11.0     11.0       12     12.0     11.0     12.0        13
#
#     11:30:00  12:30:00
# 14      22.0        23
# 15      29.0        28
# 16      23.0        24
# 17      14.0        15

# %%
df.dropna(how="all")
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
data.fillna(0)
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 1     43598  300.00         139   961.00
# 2     43599  245.00         107   880.67
# 3     43600  250.00         112  1084.94
# 4     43602  258.00         115   890.87
# ...     ...     ...         ...      ...
# 1460  48363    0.00           3     0.32
# 1461  48370    0.03          19     3.15
# 1462  48375    0.00           7     0.00
# 1463  48376    0.00           3     0.00
# 1464  48395    0.22          14     2.04
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Drug_Name', 'Parameter', '1:30:00', '2:30:00', '3:30:00',
#        '4:30:00', '5:30:00', '6:30:00', '7:30:00', '8:30:00', '9:30:00',
#        '10:30:00', '11:30:00', '12:30:00'],
#       dtype='object')

# %%
pd.melt(df,
        id_vars=["Date","Drug_Name","Parameter"])
# Out:
#            Date                Drug_Name    Parameter  variable  value
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00   23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00   12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00    NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00    NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00   24.0
# ..          ...                      ...          ...       ...    ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00   14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00   23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00   28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00   24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00   15.0
#
# [216 rows x 5 columns]

# %%
pd.melt(df,
        id_vars=["Date","Drug_Name","Parameter"]).shape
# Out:
# (216, 5)

# %%
df_melt=pd.melt(df,
        id_vars=["Date","Drug_Name","Parameter"],
        var_name="Time",
        value_name="Result")

# %%
df_melt
# Out:
#            Date                Drug_Name    Parameter      Time  Result
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00    23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00    12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00     NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00     NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00    24.0
# ..          ...                      ...          ...       ...     ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00    14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00    23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00    28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00    24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00    15.0
#
# [216 rows x 5 columns]

# %%
df_melt.pivot(index=["Date","Drug_Name","Parameter"],
                columns="Time",
                values="Result")
# Out:
# Time                                            10:30:00  11:30:00  12:30:00  \
# Date       Drug_Name               Parameter
# 15-10-2020 diltiazem hydrochloride Pressure         18.0      19.0      20.0
#                                    Temperature      20.0      20.0      21.0
#            docetaxel injection     Pressure         26.0      29.0      28.0
#                                    Temperature      23.0      25.0      25.0
#            ketamine hydrochloride  Pressure          9.0       9.0      11.0
#                                    Temperature      22.0      21.0      20.0
# 16-10-2020 diltiazem hydrochloride Pressure         24.0       NaN      27.0
#                                    Temperature      40.0       NaN      42.0
#            docetaxel injection     Pressure         28.0      29.0      30.0
#                                    Temperature      56.0      57.0      58.0
#            ketamine hydrochloride  Pressure         16.0      17.0      18.0
# ...

# %%
df_melt.pivot(index=["Date","Drug_Name","Time"],
                columns="Parameter",
                values="Result")
# Out:
# Parameter                                    Pressure  Temperature
# Date       Drug_Name               Time
# 15-10-2020 diltiazem hydrochloride 10:30:00      18.0         20.0
#                                    11:30:00      19.0         20.0
#                                    12:30:00      20.0         21.0
#                                    1:30:00       12.0         23.0
#                                    2:30:00       13.0         22.0
# ...                                               ...          ...
# 17-10-2020 ketamine hydrochloride  5:30:00       11.0         17.0
#                                    6:30:00       12.0         18.0
#                                    7:30:00       12.0         19.0
#                                    8:30:00       11.0         20.0
#                                    9:30:00       12.0         21.0
#
# [108 rows x 2 columns]

# %%
df_tidy=df_melt.pivot(index=["Date","Drug_Name","Time"],
                columns="Parameter",
                values="Result").reset_index()
df_tidy
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 20.0
# 2                 21.0
# 3                 23.0
# 4                 22.0
# ...

# %%
df_tidy.isna().sum()
# Out:
# Parameter
# Pressure       13
# Temperature    13
# dtype: int64

# %%
df_tidy[df_tidy["Drug_Name"]=="diltiazem hydrochloride"]
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# 5          15-10-2020  diltiazem hydrochloride   3:30:00       NaN
# 6          15-10-2020  diltiazem hydrochloride   4:30:00      11.0
# 7          15-10-2020  diltiazem hydrochloride   5:30:00      13.0
# 8          15-10-2020  diltiazem hydrochloride   6:30:00      14.0
# 9          15-10-2020  diltiazem hydrochloride   7:30:00      16.0
# 10         15-10-2020  diltiazem hydrochloride   8:30:00      16.0
# 11         15-10-2020  diltiazem hydrochloride   9:30:00      24.0
# 36         16-10-2020  diltiazem hydrochloride  10:30:00      24.0
# ...

# %%
df1=pd.DataFrame([[np.nan, 2, np.nan, 0],
[3, 4, np.nan, 1],
[np.nan, np.nan, np.nan, np.nan],
[np.nan, 3, np.nan, 4]],
columns=["A","B","C","D"])
df1
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  3.0 NaN  4.0

# %%
df1["B"].fillna(df1["B"].mean())
# Out:
# 0    2.0
# 1    4.0
# 2    3.0
# 3    3.0
# Name: B, dtype: float64

# %%
df1["D"].fillna(df1["D"].mean())
# Out:
# 0    0.000000
# 1    1.000000
# 2    1.666667
# 3    4.000000
# Name: D, dtype: float64

# %%
df1.fillna(df1["D"].mean())
# Out:
#           A         B         C         D
# 0  1.666667  2.000000  1.666667  0.000000
# 1  3.000000  4.000000  1.666667  1.000000
# 2  1.666667  1.666667  1.666667  1.666667
# 3  1.666667  3.000000  1.666667  4.000000

# %% [markdown]
# ### HW to fill the NAN of every column with their respective means

# %%
df_tidy["Pressure"]=df_tidy.groupby("Drug_Name")["Pressure"].transform(lambda x:x.fillna(x.mean()))

# %%
df_tidy["Temperature"]=df_tidy.groupby("Drug_Name")["Temperature"].transform(lambda x:x.fillna(x.mean()))

# %%
df_tidy.isna().sum()
# Out:
# Parameter
# Date           0
# Drug_Name      0
# Time           0
# Pressure       0
# Temperature    0
# dtype: int64

# %%
df_tidy
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 20.0
# 2                 21.0
# 3                 23.0
# 4                 22.0
# ...

# %%
df_tidy.pivot_table(index="Drug_Name",
                    columns="Date")
# Out:
# Parameter                 Pressure                       Temperature  \
# Date                    15-10-2020 16-10-2020 17-10-2020  15-10-2020
# Drug_Name
# diltiazem hydrochloride  15.952020  21.952020   8.368687   21.737374
# docetaxel injection      25.077957  26.873656  24.500000   23.962366
# ketamine hydrochloride    9.983871  14.322581  11.500000   22.094086
#
# Parameter
# Date                    16-10-2020 17-10-2020
# Drug_Name
# diltiazem hydrochloride  36.404040   16.40404
# docetaxel injection      49.698925   17.50000
# ketamine hydrochloride   12.534946   18.50000

# %%
df_tidy.pivot_table?

# %%
df_tidy.pivot_table(index="Drug_Name",
                    columns="Date",
                    aggfunc=np.min)
# Out:
# Parameter                 Pressure                       Temperature  \
# Date                    15-10-2020 16-10-2020 17-10-2020  15-10-2020
# Drug_Name
# diltiazem hydrochloride       11.0  15.424242        3.0   20.000000
# docetaxel injection           22.0  23.000000       20.0   17.000000
# ketamine hydrochloride         7.0  11.935484        8.0   17.709677
#
# Parameter                                           Time
# Date                    16-10-2020 17-10-2020 15-10-2020 16-10-2020 17-10-2020
# Drug_Name
# diltiazem hydrochloride  24.848485       10.0   10:30:00   10:30:00   10:30:00
# docetaxel injection      30.387097       12.0   10:30:00   10:30:00   10:30:00
# ketamine hydrochloride    8.000000       13.0   10:30:00   10:30:00   10:30:00

# %%
df_tidy.pivot_table(index="Drug_Name",
                    columns="Date",
                    aggfunc=np.min,
                    margins=True)
# Out:
# Parameter                 Pressure                             Temperature  \
# Date                    15-10-2020 16-10-2020 17-10-2020   All  15-10-2020
# Drug_Name
# diltiazem hydrochloride       11.0  15.424242        3.0   3.0        20.0
# docetaxel injection           22.0       23.0       20.0  20.0        17.0
# ketamine hydrochloride         7.0  11.935484        8.0   7.0   17.709677
# All                            7.0  11.935484        3.0   3.0        17.0
#
# Parameter                                                 Time             \
# Date                    16-10-2020 17-10-2020   All 15-10-2020 16-10-2020
# Drug_Name
# diltiazem hydrochloride  24.848485       10.0  10.0   10:30:00   10:30:00
# docetaxel injection      30.387097       12.0  12.0   10:30:00   10:30:00
# ketamine hydrochloride         8.0       13.0   8.0   10:30:00   10:30:00
# All                            8.0       10.0   8.0   10:30:00   10:30:00
#
# Parameter
# ...

# %%
df_tidy
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 20.0
# 2                 21.0
# 3                 23.0
# 4                 22.0
# ...

# %%
pd.cut(df_tidy["Temperature"],
       bins=,
       labels=)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-03908f6f29dd> in <module>
# ----> 1 pd.cut()
#
# TypeError: cut() missing 2 required positional arguments: 'x' and 'bins'

# %%
temp_bins=[5,20,35,50,60]
temp_labels=["low","medium","high","very_high"]
df_tidy["Temp_cat"] = pd.cut(df_tidy["Temperature"],
       bins=temp_bins,
       labels=temp_labels,
       right=False)

# %%
df_tidy
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature Temp_cat
# 0                 20.0   medium
# 1                 20.0   medium
# 2                 21.0   medium
# ...
